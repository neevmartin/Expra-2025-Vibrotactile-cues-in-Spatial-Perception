# %%
from vibration_controller import VibrationController
import time
vib = VibrationController()
# Out:
# Port= COM3
# VibrationController COM3 (6 PWM pins) initialized with max_volt=3, power_source=5, voltage_scalar=0.6 (Testing mode: False)

# %%
# vib.vibrate(0.28,0.2)
# time.sleep(1)
# vib.vibrate(0.4,0.2)
# time.sleep(1)
# vib.vibrate(0.52, 0.2)
# time.sleep(1)
# vib.vibrate(0.64, 0.2)
# time.sleep(1)
# vib.vibrate(0.76, 0.2)
# time.sleep(1)
# vib.vibrate(0.88, 0.2)
# time.sleep(1)
# vib.vibrate(1, 0.2)

vib.vibrate(0.28, 0.2)
time.sleep(1)
vib.vibrate(0.52, 0.2)
time.sleep(1)
vib.vibrate(0.76, 0.2)
time.sleep(1)
vib.vibrate(1, 0.2)
# Out:
# Vibrate at intensity 1 for 1 seconds.
# ---------------------------------------------------------------------------
# SerialException                           Traceback (most recent call last)
# Cell In[155], line 15
#       1 # vib.vibrate(0.28,0.2)
#       2 # time.sleep(1)
#       3 # vib.vibrate(0.4,0.2)
#    (...)
#      12 # time.sleep(1)
#      13 # vib.vibrate(1, 0.2)
# ---> 15 vib.vibrate(1, 1)
#      16 time.sleep(1)
#      17 vib.vibrate(0.52, 0.2)
#
# File c:\Users\scl-l\Documents\expra-2025-vibrotactile-cues-in-spatial-perception\Experiment_Code\vibration_controller.py:84, in VibrationController.vibrate(self, intensity, duration_sec)
#      82         return
#      83 for pin in self.pins:
# ---> 84     pin.write(intensity * self.voltage_scalar) # Set intensity of the vibration
#      85 time.sleep(duration_sec)
#      86 # Deactivate vibration
#
# ...
